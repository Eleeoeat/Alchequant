# %% [markdown]
# # Notebook 04：第一个策略 - 双均线交叉
#
# 目标：使用当前回测封装运行 `SmaCross`，避免手写 Cerebro 配置遗漏仓位管理器。

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

DB_PATH = ROOT / 'data' / 'stocks.db'
print(f'项目根目录: {ROOT}')
print(f'数据库: {DB_PATH}')

# %%
from src.backtest import run_backtest_detailed
from src.strategy import SmaCross

result = run_backtest_detailed(
    '000001',
    SmaCross,
    db_path=str(DB_PATH),
    cash=100000,
    commission=0.001,
    position_pct=95,
    strategy_params={'fast': 5, 'slow': 20},
)
result['summary']

# %%
trades = result['trades']
print(f'交易笔数: {len(trades)}')
trades[:3]

# %%
equity = result['equity_curve']
equity.tail()

# %% [markdown]
# 小结：正式回测入口是 `run_backtest_detailed()`，它会返回摘要、交易明细、净值曲线和原始行情。
